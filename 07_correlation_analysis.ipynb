# %% [markdown]
# # Correlation and distance analysis between Gene expression and ATAC-seq data

# %% [markdown]
# After analyzing the ATAC-seq and RNA-seq datasets doing different clusters we want to see how gene expression and ATAC-seq regions correlate and analyze the distance between genes and CREs. This will give use important information to uncover regulatory programms from ILCs.

# %% [markdown]
# In this Notebook we are going to be solving the following questions:
#
# 2. iii Can one use correlation analysis and distance information to associate ATAC-seq regions with gene expression?
#
# a) Where are associated CREs located with respect to the TSS?
# b) Where are the most associated CREs located?
# c) How many CREs are associated with genes?
# d) Is every promoter associated with a gene?
# e) Are some promoters associated with other genes?
# f) What is the closest associated CRE to a gene?
# g) Are there CREs that control several genes?
#
# To do this, we are going to use different statistical methods such as Pearson correlation. The results are visualized in some cases using plots, histograms and heatmaps.

# %% [markdown]
# 1. Load the datasets, filtering, obtaining TSS per each gene and associating OCRs with near genes

# %%
import pandas as pd
import numpy as np
from scipy.stats import pearsonr
import matplotlib.pyplot as plt

# %%
atac = pd.read_csv("data/ImmGenATAC18_AllOCRsInfo.csv")
rna = pd.read_csv("data/mmc2.csv")
refflat = pd.read_csv("data/refFlat.txt", sep="\t", header=None)
refflat.columns = [
    "geneName", "name2", "chrom", "strand", "txStart", "txEnd",
    "cdsStart", "cdsEnd", "exonCount", "exonStarts", "exonEnds"
]

# %%
cell_types = [
    "NK.27+11b-.BM", "NK.27+11b+.BM", "NK.27-11b+.BM",
    "NK.27+11b-.Sp", "NK.27+11b+.Sp", "NK.27-11b+.Sp",
    "ILC2.SI", "ILC3.NKp46-CCR6-.SI", "ILC3.NKp46+.SI", "ILC3.CCR6+.SI"
]

# %%
rna = rna.rename(columns={"Unnamed: 0": "gene"})
rna_filtered = rna.set_index("gene")[cell_types]

atac = atac[atac[cell_types].notnull().all(axis=1)].copy()
atac["midpoint"] = atac["Summit"]
atac_filtered = atac[["ImmGenATAC1219.peakID", "chrom", "midpoint", "genes.within.100Kb"] + cell_types]

# %%
refflat["TSS"] = np.where(refflat["strand"] == "+", refflat["txStart"], refflat["txEnd"])
gene_tss = refflat[["geneName", "chrom", "TSS"]].drop_duplicates()

# %% [markdown]
# The following code is used to find associations between OCRs and Genes without filtering for correlation. This means that negative correlations are also considered. CREs that correlate negatively with Genes are probably repressors. The Pie chart shows in which genomic category are the OCRs located.

# %%
rows = []
window = 100_000

for i, row in atac_filtered.iterrows():
    peak_id = row["ImmGenATAC1219.peakID"]
    chrom = row["chrom"]
    midpoint = row["midpoint"]
    signal = row[cell_types].values
    if pd.isna(row["genes.within.100Kb"]):
        continue

    genes = [g.strip() for g in str(row["genes.within.100Kb"]).split(";")]
    for gene in genes:
        if gene in rna_filtered.index and gene_tss["geneName"].eq(gene).any():
            gene_row = gene_tss[gene_tss["geneName"] == gene]
            gene_chrom = gene_row["chrom"].values[0]
            tss = gene_row["TSS"].values[0]

            if gene_chrom != chrom:
                continue

            expr = rna_filtered.loc[gene].values
            corr, _ = pearsonr(signal, expr)

            rows.append({
                "ocr_id": peak_id,
                "gene": gene,
                "chrom": chrom,
                "distance": midpoint - tss,
                "abs_distance": abs(midpoint - tss),
                "correlation": corr
            })

all_assoc_df = pd.DataFrame(rows)
print("Associations OCR ↔ gen:", all_assoc_df.shape)
# Out:
# /var/folders/cy/bvr0t8gn719b64ym133x5y7m0000gn/T/ipykernel_1645/4101964422.py:23: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   corr, _ = pearsonr(signal, expr)
# Associations OCR ↔ gen: (98593, 6)

# %%
pip install pandas matplotlib intervaltree
# Out:
# Requirement already satisfied: pandas in /Users/paulagutierrezposse/miniconda3/envs/data_analysis/lib/python3.9/site-packages (2.2.3)
# Requirement already satisfied: matplotlib in /Users/paulagutierrezposse/miniconda3/envs/data_analysis/lib/python3.9/site-packages (3.9.4)
# Collecting intervaltree
#   Downloading intervaltree-3.1.0.tar.gz (32 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.22.4 in /Users/paulagutierrezposse/miniconda3/envs/data_analysis/lib/python3.9/site-packages (from pandas) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/paulagutierrezposse/miniconda3/envs/data_analysis/lib/python3.9/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/paulagutierrezposse/miniconda3/envs/data_analysis/lib/python3.9/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/paulagutierrezposse/miniconda3/envs/data_analysis/lib/python3.9/site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/paulagutierrezposse/miniconda3/envs/data_analysis/lib/python3.9/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/paulagutierrezposse/miniconda3/envs/data_analysis/lib/python3.9/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/paulagutierrezposse/miniconda3/envs/data_analysis/lib/python3.9/site-packages (from matplotlib) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/paulagutierrezposse/miniconda3/envs/data_analysis/lib/python3.9/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Users/paulagutierrezposse/miniconda3/envs/data_analysis/lib/python3.9/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/paulagutierrezposse/miniconda3/envs/data_analysis/lib/python3.9/site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/paulagutierrezposse/miniconda3/envs/data_analysis/lib/python3.9/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/paulagutierrezposse/miniconda3/envs/data_analysis/lib/python3.9/site-packages (from matplotlib) (6.5.2)
# Collecting sortedcontainers<3.0,>=2.0 (from intervaltree)
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: zipp>=3.1.0 in /Users/paulagutierrezposse/miniconda3/envs/data_analysis/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.21.0)
# Requirement already satisfied: six>=1.5 in /Users/paulagutierrezposse/miniconda3/envs/data_analysis/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Building wheels for collected packages: intervaltree
#   DEPRECATION: Building 'intervaltree' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'intervaltree'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for intervaltree (setup.py) ... done
#   Created wheel for intervaltree: filename=intervaltree-3.1.0-py2.py3-none-any.whl size=26191 sha256=54fffef213be22f64f9213a64b9ef605421c027c780b8d83802b21ebb2046d4d
#   Stored in directory: /Users/paulagutierrezposse/Library/Caches/pip/wheels/ab/fa/1b/75d9a713279796785711bd0bad8334aaace560c0bd28830c8c
# Successfully built intervaltree
# Installing collected packages: sortedcontainers, intervaltree
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [intervaltree]
# Successfully installed intervaltree-3.1.0 sortedcontainers-2.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from intervaltree import IntervalTree
import matplotlib.pyplot as plt
from collections import defaultdict

ocr_df = pd.read_csv("./data/ImmGenATAC18_AllOCRsInfo.csv")
print(ocr_df.columns.tolist())
refFlat = pd.read_csv("./data/refFlat.txt", sep="\t", header=None)

refFlat.columns = [
    "geneName", "name", "chrom", "strand", "txStart", "txEnd",
    "cdsStart", "cdsEnd", "exonCount", "exonStarts", "exonEnds"
]

promoters, exons, genes = defaultdict(IntervalTree), defaultdict(IntervalTree), defaultdict(IntervalTree)

for _, row in refFlat.iterrows():
    chrom = row["chrom"]
    strand = row["strand"]
    tx_start, tx_end = row["txStart"], row["txEnd"]
    tss = tx_start if strand == "+" else tx_end

    p_start = tss - 1000 if strand == "+" else tss - 100
    p_end   = tss + 100  if strand == "+" else tss + 1000
    promoters[chrom].addi(p_start, p_end)

    genes[chrom].addi(tx_start, tx_end)

    exon_starts = list(map(int, row["exonStarts"].strip(",").split(",")))
    exon_ends = list(map(int, row["exonEnds"].strip(",").split(",")))
    for start, end in zip(exon_starts, exon_ends):
        exons[chrom].addi(start, end)

def classify_ocr(row):
    chrom, start, end = row["chr"], row["start"], row["end"]
    if chrom not in promoters:
        return "Intergenic"
    if promoters[chrom].overlaps(start, end):
        return "Promoter"
    elif exons[chrom].overlaps(start, end):
        return "Exon"
    elif genes[chrom].overlaps(start, end):
        return "Intron"
    else:
        return "Intergenic"

ocr_df = ocr_df.rename(columns={"chrom": "chr"})
ocr_df["start"] = ocr_df["Summit"] - 250
ocr_df["end"] = ocr_df["Summit"] + 250
ocr_df = ocr_df.rename(columns=lambda x: x.lower())

ocr_df["annotation"] = ocr_df.apply(classify_ocr, axis=1)

counts = ocr_df["annotation"].value_counts(normalize=True) * 100

plt.figure(figsize=(6, 6))
counts.plot(kind="pie", autopct="%.1f%%", startangle=90, ylabel="")
plt.title("Distribution of OCRs")
plt.tight_layout()
plt.savefig("Distribution_of_OCRs.png", dpi=300)
plt.show()
# Out:
# ['ImmGenATAC1219.peakID', 'chrom', 'Summit', 'mm10.60way.phastCons_scores', '_-log10_bestPvalue', 'Included.in.systematic.analysis', 'TSS', 'genes.within.100Kb', 'LTHSC.34-.BM', 'LTHSC.34+.BM', 'STHSC.150-.BM', 'MPP4.135+.BM', 'proB.CLP.BM', 'proB.FrA.BM', 'proB.FrBC.BM', 'preB.FrD.BM', 'B.FrE.BM', 'B1b.PC', 'B.T1.Sp', 'B.T2.Sp', 'B.T3.Sp', 'B.Sp', 'B.Fem.Sp', 'B.MZ.Sp', 'B.Fo.Sp', 'B.mem.Sp', 'B.GC.CB.Sp', 'B.GC.CC.Sp', 'B.PB.Sp', 'B.PC.Sp', 'B.PC.BM', 'preT.DN1.Th', 'preT.DN2a.Th', 'preT.DN2b.Th', 'preT.DN3.Th', 'T.DN4.Th', 'T.ISP.Th', 'T.DP.Th', 'T.4.Th', 'T.8.Th', 'T.4.Nve.Sp', 'T.4.Nve.Fem.Sp', 'T.8.Nve.Sp', 'T.4.Sp.aCD3+CD40.18hr', 'Treg.4.FP3+.Nrplo.Co', 'Treg.4.25hi.Sp', 'T8.TN.P14.Sp', 'T8.IEL.LCMV.d7.SI', 'T8.TE.LCMV.d7.Sp', 'T8.MP.LCMV.d7.Sp', 'T8.Tcm.LCMV.d180.Sp', 'T8.Tem.LCMV.d180.Sp', 'NKT.Sp', 'NKT.Sp.LPS.3hr', 'NKT.Sp.LPS.18hr', 'NKT.Sp.LPS.3d', 'Tgd.g2+d17.24a+.Th', 'Tgd.g2+d17.LN', 'Tgd.g2+d1.24a+.Th', 'Tgd.g2+d1.LN', 'Tgd.g1.1+d1.24a+.Th', 'Tgd.g1.1+d1.LN', 'Tgd.Sp', 'NK.27+11b-.BM', 'NK.27+11b+.BM', 'NK.27-11b+.BM', 'NK.27+11b-.Sp', 'NK.27+11b+.Sp', 'NK.27-11b+.Sp', 'ILC2.SI', 'ILC3.NKp46-CCR6-.SI', 'ILC3.NKp46+.SI', 'ILC3.CCR6+.SI', 'MPP3.48+.BM', 'GN.BM', 'GN.Sp', 'GN.Thio.PC', 'Mo.6C+II-.Bl', 'Mo.6C-II-.Bl', 'MF.pIC.Alv.Lu', 'MF.226+II+480lo.PC', 'MF.ICAM+480hi.PC', 'MF.RP.Sp', 'MF.LP.SI', 'MF.Alv.Lu', 'MF.microglia.CNS', 'MF.PC', 'MF.Fem.PC', 'DC.4+.Sp', 'DC.8+.Sp', 'DC.pDC.Sp', 'DC.103+11b+.SI', 'DC.103+11b-.SI', 'FRC.SLN', 'IAP.SLN', 'BEC.SLN', 'LEC.SLN', 'Ep.MEChi.Th']

# %% [markdown]
# # Enhancers and Promoters

# %% [markdown]
# This code also finds associations between OCRs and Genes but filters for only positive correlations. This means that all associated CREs that are found have to be enhancers or promoters. For this part of the analysis we are going to use this code to find promoters or enhancers.

# %%
from scipy.stats import pearsonr
import pandas as pd

rows = []
window = 100_000

for i, row in atac_filtered.iterrows():
    peak_id = row["ImmGenATAC1219.peakID"]
    chrom = row["chrom"]
    midpoint = row["midpoint"]
    signal = row[cell_types].values

    if pd.isna(row["genes.within.100Kb"]):
        continue

    genes = [g.strip() for g in str(row["genes.within.100Kb"]).split(";")]
    for gene in genes:
        if gene in rna_filtered.index and gene_tss["geneName"].eq(gene).any():
            gene_row = gene_tss[gene_tss["geneName"] == gene]
            gene_chrom = gene_row["chrom"].values[0]
            tss = gene_row["TSS"].values[0]

            if gene_chrom != chrom:
                continue

            expr = rna_filtered.loc[gene].values
            corr, _ = pearsonr(signal, expr)

            if corr > 0: 
                rows.append({
                    "ocr_id": peak_id,
                    "gene": gene,
                    "chrom": chrom,
                    "distance": midpoint - tss,
                    "abs_distance": abs(midpoint - tss),
                    "correlation": corr
                })

assoc_df = pd.DataFrame(rows)

print("Associations OCR ↔ gen (correlation > 0):", assoc_df.shape)
print("Average Correlation:", assoc_df["correlation"].mean())
# Out:
# /var/folders/cy/bvr0t8gn719b64ym133x5y7m0000gn/T/ipykernel_1645/1215522302.py:27: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   corr, _ = pearsonr(signal, expr)
# Associations OCR ↔ gen (correlation > 0): (49990, 6)
# Average Correlation: 0.3662783731220586

# %% [markdown]
# 2. Calculating average correlation to see if it is viable to use it for further analysis. The average correlation is 0.37. This means that Gene expression correlates very well with Chromatin Accesibility and can be used to find CREs.

# %%
print("Average Correlation:", assoc_df["correlation"].mean())
# Out:
# Average Correlation: 0.3662783731220586

# %% [markdown]
# 3. Answering question a). We can determine from the plot that Activators are located mostly on TSSs or very close to them.

# %%
plt.figure()
assoc_df["distance"].hist(bins=300)
plt.title("Distance Activator ↔ TSS")
plt.xlabel("Distance (bp)")
plt.ylabel("N° associations")
plt.savefig("Distance_Activators-TSS.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# 4. Answering question b). The following table shows how far away are the most associated Activators to each gene located and to which genomic category they belong.

# %%
top_assoc = assoc_df.sort_values(by="correlation", ascending=False)
print("TOP 10 more associated CREs:\n", top_assoc)

plt.figure(figsize=(8, 6))
plt.scatter(top_assoc["abs_distance"], top_assoc["correlation"], alpha=0.8)
plt.xlabel("Distance to TSS (bp)")
plt.ylabel("Correlation")
plt.title("Top 50 OCR–Gene Associations")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# TOP 10 more associated CREs:
#                             ocr_id           gene  chrom  distance  \
# 20196  ImmGenATAC1219.peak_203677           Ets2  chr16     46963
# 10306  ImmGenATAC1219.peak_108346  9430078K24Rik  chr12    -67017
# 42191  ImmGenATAC1219.peak_428162           Nav2   chr7    292471
# 37453  ImmGenATAC1219.peak_375291         Ptpn13   chr5     72435
# 15663  ImmGenATAC1219.peak_161017           Klf5  chr14      9258
# ...                           ...            ...    ...       ...
# 261      ImmGenATAC1219.peak_1328         Gm5523   chr1     23118
# 12079  ImmGenATAC1219.peak_125344           Nrn1  chr13     24554
# 17131  ImmGenATAC1219.peak_170309          Rrm2b  chr15    -27525
# 34888  ImmGenATAC1219.peak_344000          Glis1   chr4     49548
# 26078  ImmGenATAC1219.peak_260326           Rsu1   chr2    -66648
#
#        abs_distance  correlation
# 20196         46963     0.999173
# 10306         67017     0.999055
# 42191        292471     0.998503
# 37453         72435     0.998258
# 15663          9258     0.998164
# ...             ...          ...
# 261           23118     0.000047
# 12079         24554     0.000033
# 17131         27525     0.000027
# 34888         49548     0.000026
# 26078         66648     0.000016
#
# [49990 rows x 6 columns]

# %%
print(ocr_df[["immgenatac1219.peakid", "annotation"]].head())
# Out:
#    immgenatac1219.peakid  annotation
# 0  ImmGenATAC1219.peak_1  Intergenic
# 1  ImmGenATAC1219.peak_2  Intergenic
# 2  ImmGenATAC1219.peak_3  Intergenic
# 3  ImmGenATAC1219.peak_4  Intergenic
# 4  ImmGenATAC1219.peak_5      Intron

# %%
ocr_df = ocr_df.rename(columns={"immgenatac1219.peakid": "ocr_id"})

# %%
assoc_annotated = assoc_df.merge(ocr_df[["ocr_id", "annotation"]], on="ocr_id", how="left")

# %%
top_assoc = assoc_annotated.sort_values(by="correlation", ascending=False)

plt.figure(figsize=(6, 4))
top_assoc["annotation"].value_counts().plot(kind="bar", color="lightcoral")
plt.title("Genomic Category of Top OCR-Gene Associations")
plt.ylabel("Count")
plt.xlabel("Annotation")
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("Genomic_Category_of_Top_OCR-Gene_Associations.png", dpi=300)
plt.show()

# %% [markdown]
# This code allows us to compare the location of most associated Repressors and Activators. It also shows most associated CREs to each gene without differentiating between Activators and Repressors and visualizes it on a heatmap.

# %%
closest_activ = assoc_df.loc[assoc_df.groupby("gene")["correlation"].idxmax()].copy()
closest_repr = repr_assoc_df.loc[repr_assoc_df.groupby("gene")["correlation"].idxmin()].copy()

closest_activ["type"] = "Activator"
closest_repr["type"] = "Repressor"

closest_all = pd.concat([closest_activ, closest_repr])
import seaborn as sns

plt.figure(figsize=(8, 4))
sns.countplot(data=closest_all, x="annotation", hue="type")
plt.title("Genomic Category of the most associated OCRs with Genes")
plt.xlabel("Genomic Category")
plt.ylabel("Quantity of Genes")
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("Genomic_Categories_more_associated_CRE.png", dpi=300)
plt.show()

# %%
all_assoc = pd.concat([assoc_df, repr_assoc_df], ignore_index=True)

all_assoc["ocr_id"] = all_assoc["ocr_id"].astype(str)

strongest_assoc = all_assoc.loc[all_assoc.groupby("gene")["correlation"].apply(lambda x: x.abs().idxmax())]

strongest_activ = assoc_df.loc[assoc_df.groupby("gene")["correlation"].idxmax()]

strongest_repr = repr_assoc_df.loc[repr_assoc_df.groupby("gene")["correlation"].idxmin()]

print("Most associated OCR for each Gene:\n", strongest_assoc.head())
print("Most associated OCR for each Gene (Activators):\n", strongest_activ.head())
print("Most associated OCR for each Gene (Repressors):\n", strongest_repr.head())
# Out:
# Most associated OCR for each Gene:
#                             ocr_id           gene  chrom  distance  \
# 17541   ImmGenATAC1219.peak_85677  0610039H22Rik  chr11  -19607.0
# 72420  ImmGenATAC1219.peak_367970  0610040J01Rik   chr5   14711.0
# 61813  ImmGenATAC1219.peak_307974  1110032F04Rik   chr3    -284.0
# 12305   ImmGenATAC1219.peak_55493  1500009L16Rik  chr10   53805.0
# 40496  ImmGenATAC1219.peak_203751  1600002D24Rik  chr16  -73591.0
#
#        abs_distance  correlation annotation
# 17541       19607.0     0.816311        NaN
# 72420       14711.0     0.685825        NaN
# 61813         284.0     0.920106        NaN
# 12305       53805.0    -0.482544        NaN
# 40496       73591.0     0.749388        NaN
# Most associated OCR for each Gene (Activators):
#                             ocr_id           gene  chrom  distance  \
# 17541   ImmGenATAC1219.peak_85677  0610039H22Rik  chr11  -19607.0
# 72420  ImmGenATAC1219.peak_367970  0610040J01Rik   chr5   14711.0
# 61813  ImmGenATAC1219.peak_307974  1110032F04Rik   chr3    -284.0
# 12311   ImmGenATAC1219.peak_55499  1500009L16Rik  chr10   83697.0
# 40496  ImmGenATAC1219.peak_203751  1600002D24Rik  chr16  -73591.0
#
#        abs_distance  correlation
# 17541       19607.0     0.816311
# 72420       14711.0     0.685825
# 61813         284.0     0.920106
# 12311       83697.0     0.310255
# 40496       73591.0     0.749388
# Most associated OCR for each Gene (Repressors):
#                             ocr_id           gene  chrom  distance  \
# 8818    ImmGenATAC1219.peak_85647  0610039H22Rik  chr11    -63669
# 35782  ImmGenATAC1219.peak_367955  0610040J01Rik   chr5    -45517
# 30580  ImmGenATAC1219.peak_307983  1110032F04Rik   chr3     26054
# 6118    ImmGenATAC1219.peak_55493  1500009L16Rik  chr10     53805
# 20256  ImmGenATAC1219.peak_203730  1600002D24Rik  chr16   -103704
#
#        abs_distance  correlation  annotation
# 8818          63669    -0.591290      Intron
# 35782         45517    -0.550440      Intron
# 30580         26054    -0.439101      Intron
# 6118          53805    -0.482544  Intergenic
# 20256        103704    -0.568691  Intergenic

# %%
import seaborn as sns
import matplotlib.pyplot as plt

top50 = strongest_assoc.loc[strongest_assoc["correlation"].abs().sort_values(ascending=False).index[:50]]
pivot_top = top50.pivot(index="gene", columns="ocr_id", values="correlation")

sns.heatmap(pivot_top, cmap="coolwarm", center=0)
plt.title("Top 50 OCRs associated with Genes (by correlation)")
plt.xlabel("OCR ID")
plt.ylabel("Gene")
plt.savefig("Top_50_OCRs_associated_with_Genes.png", dpi=300)

# %% [markdown]
# 5. Answering question c). There are 98593 OCRs associated to genes, from those 49990 have a positive correlation.

# %%
print("CREs associated to genes:", assoc_df["ocr_id"].nunique())
# Out:
# CREs associated to genes: 49990

# %% [markdown]
# 6. Answering question d) and e). There are 1397 genes with Activators on their promoters, a small number when compared to the total numbers of CREs associated to genes. There are no promoters associated with more than 1 gene.

# %%
import pandas as pd
import numpy as np
from scipy.stats import pearsonr

atac_path = "data/ImmGenATAC18_AllOCRsInfo.csv"
rna_path = "data/mmc2.csv"
refFlat_path = "data/refFlat.txt"

atac = pd.read_csv(atac_path)
atac["midpoint"] = atac["Summit"]

cell_types = [
    "NK.27+11b-.BM", "NK.27+11b+.BM", "NK.27-11b+.BM",
    "NK.27+11b-.Sp", "NK.27+11b+.Sp", "NK.27-11b+.Sp",
    "ILC2.SI", "ILC3.NKp46-CCR6-.SI", "ILC3.NKp46+.SI", "ILC3.CCR6+.SI"
]
atac_filtered = atac[["ImmGenATAC1219.peakID", "chrom", "midpoint", "genes.within.100Kb"] + cell_types].dropna()

rna = pd.read_csv(rna_path)
rna.columns.values[0] = "gene"
rna.set_index("gene", inplace=True)
rna_filtered = rna[cell_types].dropna()

refFlat = pd.read_csv(refFlat_path, sep="\t", header=None, names=[
    "geneName", "transcript", "chrom", "strand", "txStart", "txEnd",
    "cdsStart", "cdsEnd", "exonCount", "exonStarts", "exonEnds"
])
refFlat = refFlat[refFlat["chrom"].str.startswith("chr")]
refFlat["TSS"] = np.where(refFlat["strand"] == "+", refFlat["txStart"], refFlat["txEnd"])
gene_tss = refFlat.groupby("geneName")[["chrom", "TSS"]].first().reset_index()

# %%
rows = []
for i, row in atac_filtered.iterrows():
    peak_id = row["ImmGenATAC1219.peakID"]
    chrom = row["chrom"]
    midpoint = row["midpoint"]
    signal = row[cell_types].values
    genes = str(row["genes.within.100Kb"]).split(";")

    for gene in genes:
        gene = gene.strip()
        if gene in rna_filtered.index and gene_tss["geneName"].eq(gene).any():
            gene_row = gene_tss[gene_tss["geneName"] == gene]
            gene_chrom = gene_row["chrom"].values[0]
            tss = gene_row["TSS"].values[0]
            if gene_chrom != chrom:
                continue
            expr = rna_filtered.loc[gene].values
            corr, _ = pearsonr(signal, expr)

            rows.append({
                "ocr_id": peak_id,
                "gene": gene,
                "chrom": chrom,
                "distance": midpoint - tss,
                "abs_distance": abs(midpoint - tss),
                "correlation": corr
            })

assoc_df = pd.DataFrame(rows)
assoc_df.to_csv("assoc_df.csv", index=False)
# Out:
# /var/folders/cy/bvr0t8gn719b64ym133x5y7m0000gn/T/ipykernel_6233/1939566184.py:18: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   corr, _ = pearsonr(signal, expr)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

promoter_assoc = assoc_annotated[assoc_annotated["annotation"] == "Promoter"]
genes_with_promoter = promoter_assoc["gene"].nunique()
print("Genes with Activators in promoter:", genes_with_promoter)
multi_gene_promoters = promoter_assoc.groupby("ocr_id")["gene"].nunique()
multi_gene_promoters = multi_gene_promoters[multi_gene_promoters > 1]

print("Promoters associated to more than 1 gene:", multi_gene_promoters.shape[0])
# Out:
# Genes with Activators in promoter: 1397
# Promoters associated to more than 1 gene: 0

# %% [markdown]
# 7. Answering question f). We are going to find the closest Activator to each Gene and see to which genomic category they belong to.We also compare the correlation of closest Activator when located in or outside a promoter.

# %%
closest = assoc_df.loc[assoc_df.groupby("gene")["abs_distance"].idxmin()]
print("closest Activator to each gene:\n", closest)
# Out:
# closest Activator to each gene:
#                             ocr_id           gene  chrom  distance  \
# 8719    ImmGenATAC1219.peak_85693  0610039H22Rik  chr11     -4041
# 36625  ImmGenATAC1219.peak_367961  0610040J01Rik   chr5       251
# 31235  ImmGenATAC1219.peak_307975  1110032F04Rik   chr3       -33
# 6185    ImmGenATAC1219.peak_55489  1500009L16Rik  chr10     31142
# 20235  ImmGenATAC1219.peak_203764  1600002D24Rik  chr16    -56461
# ...                           ...            ...    ...       ...
# 41992  ImmGenATAC1219.peak_421385        Zscan4d   chr7     -7899
# 13962  ImmGenATAC1219.peak_140430         Zswim6  chr13        85
# 6078    ImmGenATAC1219.peak_52182          Zwint  chr10         6
# 49301  ImmGenATAC1219.peak_507041           Zxda   chrX     29764
# 33056  ImmGenATAC1219.peak_325576           Zzz3   chr3     57353
#
#        abs_distance  correlation  annotation
# 8719           4041     0.599035      Intron
# 36625           251     0.652204    Promoter
# 31235            33     0.529263    Promoter
# 6185          31142     0.255355      Intron
# 20235         56461     0.661927      Intron
# ...             ...          ...         ...
# 41992          7899     0.233931  Intergenic
# 13962            85     0.712436    Promoter
# 6078              6     0.079528    Promoter
# 49301         29764     0.114889  Intergenic
# 33056         57353     0.530921      Intron
#
# [3556 rows x 7 columns]

# %%
ocr_df = ocr_df.rename(columns={"immgenatac1219.peakid": "ocr_id"})  # si no lo hiciste ya
closest = closest.drop(columns=[col for col in ["annotation", "annotation_x", "annotation_y"] if col in closest.columns])

closest["ocr_id"] = closest["ocr_id"].astype(str)
ocr_df["ocr_id"] = ocr_df["ocr_id"].astype(str)

closest = closest.merge(ocr_df[["ocr_id", "annotation"]], on="ocr_id", how="left")

print("annotation" in closest.columns)  
non_promoter_closest = closest[closest["annotation"] != "Promoter"]
print("Genes where the closest Activator is not in a promoter:", non_promoter_closest.shape[0])

non_promoter_closest["annotation"].value_counts().plot(
    kind="pie", autopct="%.1f%%", startangle=90, colors=["gold", "salmon", "lightblue"]
)
plt.title("Closest Activator (outside promoter)")
plt.ylabel("")
plt.tight_layout()
plt.show()
# Out:
# True
# Genes where the closest Activator is not in a promoter: 2315

# %%
import seaborn as sns

closest["is_promoter"] = closest["annotation"] == "Promoter"

plt.figure(figsize=(6, 4))
sns.boxplot(data=closest, x="is_promoter", y="correlation")
plt.xticks([0, 1], ["NO Promotor", "Promotor"])
plt.title("Correlation of the closest Activators: promotor vs no-promotor")
plt.tight_layout()
plt.savefig("Correlation_Closest_Activator_Promoter_vs_NoPromoter.png", dpi=300)
plt.show()

# %%
closest["annotation"].value_counts().plot(kind="pie", autopct="%.1f%%", startangle=90)
plt.title("Genomic category of the closest Activator to each gene")
plt.ylabel("")
plt.tight_layout()
plt.savefig("Genomic_Category_of_Closest_Activator_to_Gene.png", dpi=300)
plt.show()

# %% [markdown]
# 8. Answering question g). Yes there are many Activators that regulate more than one gene. This can be visualized in the histogram and the heatmap. This is an expected result according to biological literature. There are even genes such as Foxp1 that are associated with 383 genes.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

assoc_df = pd.read_csv("assoc_df.csv")

cre_count_per_gene = assoc_df.groupby("gene")["ocr_id"].nunique().reset_index()
cre_count_per_gene.columns = ["gene", "num_cre"]

multi_cre_genes = cre_count_per_gene[cre_count_per_gene["num_cre"] > 1]

plt.figure(figsize=(10, 5))
sns.histplot(cre_count_per_gene["num_cre"], bins=30, color="skyblue", edgecolor="black")
plt.title("Distribution of associated Activators per gene")
plt.xlabel("Number of CREs per gene")
plt.ylabel("Quantity of genes")
plt.tight_layout()
plt.savefig("Distribution_associated_Activators_per_Gene.png", dpi=300)
plt.show()

top_genes = multi_cre_genes.sort_values("num_cre", ascending=False).head(20)

plt.figure(figsize=(8, 6))
sns.heatmap(top_genes.set_index("gene"), annot=True, fmt="d", cmap="coolwarm", cbar=False)
plt.title("Top 20 genes with more associated CREs (Activators)")
plt.xlabel("Number of CREs")
plt.tight_layout()
plt.savefig("Genes_more_CREs.png", dpi=300)
plt.show()

# %% [markdown]
# 9. Visualization of closest CRE to each gene with histograms, heatmaps and barplots

# %%
import pandas as pd

atac = pd.read_csv("data/ImmGenATAC18_AllOCRsInfo.csv")
refFlat = pd.read_csv("data/refFlat.txt", sep="\t", header=None)

refFlat.columns = ["geneName", "name", "chrom", "strand", "txStart", "txEnd", "cdsStart", "cdsEnd",
                   "exonCount", "exonStarts", "exonEnds"]

refFlat["TSS"] = refFlat.apply(lambda row: row["txStart"] if row["strand"] == "+" else row["txEnd"], axis=1)
gene_tss = refFlat.groupby("geneName")[["chrom", "TSS"]].first().reset_index()

atac = atac.rename(columns={"ImmGenATAC1219.peakID": "ocr_id"})
atac["midpoint"] = atac["Summit"].astype(int)

atac_sub = atac[["ocr_id", "chrom", "midpoint"]].copy()

closest = []
for _, row in gene_tss.iterrows():
    gene, chrom, tss = row["geneName"], row["chrom"], row["TSS"]
    nearby = atac_sub[(atac_sub["chrom"] == chrom) &
                      (abs(atac_sub["midpoint"] - tss) <= 100_000)].copy()
    if not nearby.empty:
        nearby["distance"] = abs(nearby["midpoint"] - tss)
        closest_ocr = nearby.loc[nearby["distance"].idxmin()]
        closest.append({
            "gene": gene,
            "ocr_id": closest_ocr["ocr_id"],
            "distance_to_tss": closest_ocr["distance"]
        })

closest_df = pd.DataFrame(closest)
closest_df.to_csv("closest_cre_per_gene.csv", index=False)
print(closest_df.head())
# Out:
#             gene                      ocr_id  distance_to_tss
# 0  0610005C13Rik  ImmGenATAC1219.peak_427235             1003
# 1  0610009B22Rik   ImmGenATAC1219.peak_75289              163
# 2  0610009E02Rik  ImmGenATAC1219.peak_263173               25
# 3  0610009L18Rik   ImmGenATAC1219.peak_95335               68
# 4  0610010F05Rik   ImmGenATAC1219.peak_70328               94

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("closest_cre_per_gene.csv")

plt.figure(figsize=(10, 6))
sns.histplot(df["distance_to_tss"], bins=50, kde=True, color='mediumseagreen')
plt.title("Distance from the closest OCR to TSS")
plt.xlabel("Distance (bp)")
plt.ylabel("Number of genes")
plt.grid(True)
plt.tight_layout()
plt.savefig("Distance_OCR_TSS.png", dpi=300)
plt.show()

# %% [markdown]
# Most of the genes have their closest OCR near the TSS, which was expected because all genes have promoters. The situations where the closest OCR is more than 2kb away from the TSS can also be realistic because not all promoters were available by the time of the experiment.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

top_assoc = assoc_df.sort_values("correlation", ascending=False).head(50)

pivot = top_assoc.pivot(index="ocr_id", columns="gene", values="correlation")

plt.figure(figsize=(12, 8))
sns.heatmap(pivot, cmap="coolwarm", center=0)
plt.title("Correlations between OCRs and Genes (Top 100)")
plt.xlabel("Gene")
plt.ylabel("OCR")
plt.tight_layout()
plt.savefig("Correlation_OCR_Gene.png", dpi=300)
plt.show()

# %% [markdown]
# This heatmap portrays the highest correlations between OCRs and genes. As seen, many of the OCRs correlate with more than one gene. Also some genes correlate with more than one OCR, which makes sense because genes have both promoters and enhancers.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("closest_cre_per_gene.csv", nrows=None) 

df['distance_to_tss'] = pd.to_numeric(df['distance_to_tss'], errors='coerce')

df = df.dropna(subset=['distance_to_tss'])

df_top = df.sort_values("distance_to_tss", key=abs).head(70)

plt.figure(figsize=(12, 6))
plt.barh(df_top['gene'], df_top['distance_to_tss'], color="mediumslateblue")
plt.xlabel("Distance to TSS (bp)")
plt.title("Closest CREs per gene (Top 20)")
plt.gca().invert_yaxis()
plt.grid(True, axis='x', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.savefig("Closest_CREs.png", dpi=300)
plt.show()

# %% [markdown]
# This Grafic proves again that most of the closest CREs per gene are promoters and are therefore located in very close proximity to the gene

# %% [markdown]
# # Repressors

# %% [markdown]
# Next we are going to filter for negative correlations to analyze repressors.

# %%
from scipy.stats import pearsonr
import pandas as pd

rows = []
window = 100_000

for i, row in atac_filtered.iterrows():
    peak_id = row["ImmGenATAC1219.peakID"]
    chrom = row["chrom"]
    midpoint = row["midpoint"]
    signal = row[cell_types].values

    if pd.isna(row["genes.within.100Kb"]):
        continue

    genes = [g.strip() for g in str(row["genes.within.100Kb"]).split(";")]
    for gene in genes:
        if gene in rna_filtered.index and gene_tss["geneName"].eq(gene).any():
            gene_row = gene_tss[gene_tss["geneName"] == gene]
            gene_chrom = gene_row["chrom"].values[0]
            tss = gene_row["TSS"].values[0]

            if gene_chrom != chrom:
                continue

            expr = rna_filtered.loc[gene].values
            corr, _ = pearsonr(signal, expr)

            if corr < 0: 
                rows.append({
                    "ocr_id": peak_id,
                    "gene": gene,
                    "chrom": chrom,
                    "distance": midpoint - tss,
                    "abs_distance": abs(midpoint - tss),
                    "correlation": corr
                })

repr_assoc_df = pd.DataFrame(rows)

print("Associations OCR ↔ gen (correlation < 0):", repr_assoc_df.shape)
print("Average Correlation:", repr_assoc_df["correlation"].mean())
# Out:
# /var/folders/cy/bvr0t8gn719b64ym133x5y7m0000gn/T/ipykernel_1645/2445974839.py:27: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   corr, _ = pearsonr(signal, expr)
# Associations OCR ↔ gen (correlation < 0): (48602, 6)
# Average Correlation: -0.2887264720987593

# %%
import matplotlib.pyplot as plt
import seaborn as sns

ocr_df["ocr_id"] = ocr_df["ocr_id"].astype(str)
repr_assoc_df["ocr_id"] = repr_assoc_df["ocr_id"].astype(str)

repr_assoc_df = repr_assoc_df.drop(columns=[col for col in repr_assoc_df.columns if col.startswith("annotation")], errors="ignore")

repr_assoc_df = repr_assoc_df.merge(ocr_df[["ocr_id", "annotation"]], on="ocr_id", how="left")

promoter_repr_assoc = repr_assoc_df[repr_assoc_df["annotation"] == "Promoter"]

genes_with_promoter = promoter_repr_assoc["gene"].nunique()
print("Genes with repressor CREs in promoter:", genes_with_promoter)

multi_gene_promoters = promoter_repr_assoc.groupby("ocr_id")["gene"].nunique()
multi_gene_promoters = multi_gene_promoters[multi_gene_promoters > 1]
print("Repressor promoters associated to more than 1 gene:", multi_gene_promoters.shape[0])
# Out:
# Genes with repressor CREs in promoter: 1247
# Repressor promoters associated to more than 1 gene: 0

# %%
closest = repr_assoc_df.loc[repr_assoc_df.groupby("gene")["abs_distance"].idxmin()]
print("closest Repressor to each gene:\n", closest)
# Out:
# closest Repressor to each gene:
#                             ocr_id           gene  chrom  distance  \
# 8837    ImmGenATAC1219.peak_85692  0610039H22Rik  chr11     -4378
# 35785  ImmGenATAC1219.peak_367960  0610040J01Rik   chr5       -18
# 30579  ImmGenATAC1219.peak_307976  1110032F04Rik   chr3       410
# 6114    ImmGenATAC1219.peak_55487  1500009L16Rik  chr10     27517
# 20275  ImmGenATAC1219.peak_203766  1600002D24Rik  chr16    -41186
# ...                           ...            ...    ...       ...
# 41068  ImmGenATAC1219.peak_421386        Zscan4d   chr7     45193
# 13741  ImmGenATAC1219.peak_140433         Zswim6  chr13      1107
# 6021    ImmGenATAC1219.peak_52183          Zwint  chr10       256
# 48017  ImmGenATAC1219.peak_507040           Zxda   chrX     29425
# 32341  ImmGenATAC1219.peak_325578           Zzz3   chr3     65721
#
#        abs_distance  correlation  annotation
# 8837           4378    -0.284014      Intron
# 35785            18    -0.392487    Promoter
# 30579           410    -0.311457        Exon
# 6114          27517    -0.458434      Intron
# 20275         41186    -0.408454      Intron
# ...             ...          ...         ...
# 41068         45193    -0.200127  Intergenic
# 13741          1107    -0.552135    Promoter
# 6021            256    -0.089547    Promoter
# 48017         29425    -0.579574  Intergenic
# 32341         65721    -0.396329        Exon
#
# [3592 rows x 7 columns]

# %%
closest["annotation"].value_counts().plot(kind="pie", autopct="%.1f%%", startangle=90)
plt.title("Genomic category of the closest Repressor to each gene")
plt.ylabel("")
plt.tight_layout()
plt.savefig("Genomic_Category_of_Closest_Repressor_to_Gene.png", dpi=300)
plt.show()

# %% [markdown]
# Now that we have the results of closest Activators and Repressors to each Gene, we are going to compare the results with CREs in general without differentiating.

# %%
closest = all_assoc_df.loc[repr_assoc_df.groupby("gene")["abs_distance"].idxmin()]
print("closest CREs to each gene:\n", closest)
# Out:
# closest CREs to each gene:
#                             ocr_id      gene  chrom  distance  abs_distance  \
# 8837    ImmGenATAC1219.peak_38960    Cnksr3  chr10     -4695          4695
# 35785  ImmGenATAC1219.peak_176427   Trappc9  chr15    -91490         91490
# 30579  ImmGenATAC1219.peak_157734    Fndc3a  chr14    -71949         71949
# 6114    ImmGenATAC1219.peak_26030     Lamc2   chr1     11075         11075
# 20275  ImmGenATAC1219.peak_106692     Prkch  chr12     85934         85934
# ...                           ...       ...    ...       ...           ...
# 41068  ImmGenATAC1219.peak_206391    Pde10a  chr17     18012         18012
# 13741   ImmGenATAC1219.peak_60813  Ppp1r12a  chr10    -72645         72645
# 6021    ImmGenATAC1219.peak_25801      Rgl1   chr1   -168626        168626
# 48017  ImmGenATAC1219.peak_239887     Mex3c  chr18    -34620         34620
# 32341  ImmGenATAC1219.peak_165052        C6  chr15    -29368         29368
#
#        correlation
# 8837     -0.086732
# 35785     0.264511
# 30579    -0.301569
# 6114      0.262724
# 20275     0.106470
# ...            ...
# 41068    -0.053247
# 13741     0.097778
# 6021      0.668458
# 48017     0.301291
# 32341    -0.103312
#
# [3592 rows x 6 columns]

# %% [markdown]
# As seen by the following code, there are 1833 Genes associated with CREs on their promoters. There are some Genes that have both Repressors and Activators on their promoters.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

ocr_df["ocr_id"] = ocr_df["ocr_id"].astype(str)
all_assoc_df["ocr_id"] = all_assoc_df["ocr_id"].astype(str)

all_assoc_df = all_assoc_df.drop(columns=[col for col in all_assoc_df.columns if col.startswith("annotation")], errors="ignore")

all_assoc_df = all_assoc_df.merge(ocr_df[["ocr_id", "annotation"]], on="ocr_id", how="left")

promoter_all_assoc = all_assoc_df[all_assoc_df["annotation"] == "Promoter"]

genes_with_promoter = promoter_all_assoc["gene"].nunique()
print("Genes with CREs in promoter:", genes_with_promoter)

multi_gene_promoters = promoter_all_assoc.groupby("ocr_id")["gene"].nunique()
multi_gene_promoters = multi_gene_promoters[multi_gene_promoters > 1]
print("Promoters associated to more than 1 gene:", multi_gene_promoters.shape[0])

closest["ocr_id"] = closest["ocr_id"].astype(str)
ocr_df["ocr_id"] = ocr_df["ocr_id"].astype(str)

closest = closest.drop(columns=[col for col in closest.columns if col.startswith("annotation")], errors="ignore")

closest = closest.merge(ocr_df[["ocr_id", "annotation"]], on="ocr_id", how="left")
closest["annotation"].value_counts().plot(kind="pie", autopct="%.1f%%", startangle=90)
plt.title("Genomic category of the closest CRE to each gene")
plt.ylabel("")
plt.tight_layout()
plt.savefig("Genomic_Category_of_Closest_CRE_to_Gene.png", dpi=300)
plt.show()
# Out:
# Genes with CREs in promoter: 1833
# Promoters associated to more than 1 gene: 0

# %% [markdown]
# We also analyze now the distance between CREs and TSS. Most CREs are located within 100kb of the TSSs.

# %%
plt.figure()
all_assoc_df["distance"].hist(bins=300)
plt.title("Distance CRE ↔ TSS")
plt.xlabel("Distance (bp)")
plt.ylabel("N° associations")
plt.savefig("Distance_CRE-TSS.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# Next we compare where Activators and Repressors are mostly located. The numbers are very similar, but there are more Activators in Promoter regions than Repressors.

# %%
ocr_df = ocr_df.rename(columns={"immgenatac1219.peakid": "ocr_id"})

ocr_df["ocr_id"] = ocr_df["ocr_id"].astype(str)
assoc_df["ocr_id"] = assoc_df["ocr_id"].astype(str)

assoc_df = assoc_df.merge(ocr_df[["ocr_id", "annotation"]], on="ocr_id", how="left")

assoc_df = assoc_df.drop(columns=[col for col in assoc_df.columns if col.startswith("annotation_") and col != "annotation"])
if "annotation_y" in assoc_df.columns:
    assoc_df = assoc_df.rename(columns={"annotation_y": "annotation"})

activ_counts = assoc_df["annotation"].value_counts()

print("Genomic Distribution of Activators:")
print(activ_counts)

import matplotlib.pyplot as plt

activ_counts.plot(kind="pie", autopct="%.1f%%", startangle=90, colors=["lightblue", "gold", "lightcoral", "lightgreen"])
plt.ylabel("")
plt.title("Genomic Category of Activator OCRs")
plt.tight_layout()
plt.show()
# Out:
# Genomic Distribution of Activators:
# annotation
# Intron        26146
# Intergenic    18196
# Promoter       2910
# Exon           2738
# Name: count, dtype: int64

# %%
ocr_df = ocr_df.rename(columns={"immgenatac1219.peakid": "ocr_id"})

ocr_df["ocr_id"] = ocr_df["ocr_id"].astype(str)
repr_assoc_df["ocr_id"] = repr_assoc_df["ocr_id"].astype(str)

repr_counts = repr_assoc_df["annotation"].value_counts()

print("Genomic Distribution of Repressors:")
print(repr_counts)

import matplotlib.pyplot as plt

repr_counts.plot(kind="pie", autopct="%.1f%%", startangle=90, colors=["lightblue", "gold", "lightcoral", "lightgreen"])
plt.ylabel("")
plt.title("Genomic Categort of repressory OCRs")
plt.tight_layout()
plt.show()
# Out:
# Genomic Distribution of Repressors:
# annotation
# Intron        25004
# Intergenic    18708
# Exon           2564
# Promoter       2326
# Name: count, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

ocr_df["ocr_id"] = ocr_df["ocr_id"].astype(str)
assoc_df["ocr_id"] = assoc_df["ocr_id"].astype(str)
repr_assoc_df["ocr_id"] = repr_assoc_df["ocr_id"].astype(str)

assoc_df = assoc_df.merge(ocr_df[["ocr_id", "annotation"]], on="ocr_id", how="left")

assoc_df = assoc_df.drop(columns=[col for col in assoc_df.columns if col.startswith("annotation_") and col != "annotation"])
if "annotation_y" in assoc_df.columns:
    assoc_df = assoc_df.rename(columns={"annotation_y": "annotation"})

combined_df = pd.concat([assoc_df, repr_assoc_df], ignore_index=True)

total_counts = combined_df["annotation"].value_counts()

total_counts.plot(kind="pie", autopct="%.1f%%", startangle=90,
                  colors=["lightblue", "gold", "lightcoral", "lightgreen"])
plt.ylabel("")
plt.title("Genomic Category of All OCR-Gene Associations")
plt.tight_layout()
plt.savefig("Combined_OCRs_Genomic_Category.png", dpi=300)
plt.show()

# %% [markdown]
# CREs with negative Correlation repress Gene expression and can be located hundreds of kb away from tne TSS as proved by the plot comparing Distance between CRE and TSS.

# %%
plt.figure()
repr_assoc_df["distance"].hist(bins=300)
plt.title("Distance Repressor ↔ TSS")
plt.xlabel("Distance (bp)")
plt.ylabel("N° associations")
plt.savefig("Distance_Repressors-TSS.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# The following table shows the top 10 more associated repressors and where they are located.

# %%
repressors = repr_assoc_df

top_repressors = repressors.sort_values("correlation").head(10)

print(top_repressors)
# Out:
#                            ocr_id     gene  chrom  distance  abs_distance  \
# 6641    ImmGenATAC1219.peak_59286     Btg1  chr10    -17254         17254
# 28307  ImmGenATAC1219.peak_284079  Bcl2l11   chr2      2047          2047
# 48454  ImmGenATAC1219.peak_511175  Sh3kbp1   chrX    -84371         84371
# 16714  ImmGenATAC1219.peak_168330     Trio  chr15    -72541         72541
# 3295    ImmGenATAC1219.peak_28453     Fasl   chr1    -83107         83107
# 6642    ImmGenATAC1219.peak_59287     Btg1  chr10    -16997         16997
# 21041  ImmGenATAC1219.peak_217062    Rftn1  chr17    -51326         51326
# 2366    ImmGenATAC1219.peak_20139    Mgat5   chr1     23327         23327
# 40055  ImmGenATAC1219.peak_410511     Atg7   chr6     28304         28304
# 29029  ImmGenATAC1219.peak_294881    Ptpn1   chr2    -37098         37098
#
#        correlation
# 6641     -0.988247
# 28307    -0.982434
# 48454    -0.981122
# 16714    -0.977963
# 3295     -0.966194
# 6642     -0.964129
# 21041    -0.960075
# 2366     -0.959941
# 40055    -0.958700
# 29029    -0.958641

# %% [markdown]
# There are 48602 CREs that are negatively associated to genes, meaning they act as repressors.

# %%
print("CREs negatively associated to genes:", repr_assoc_df["ocr_id"].nunique())
# Out:
# CREs negatively associated to genes: 48602

# %% [markdown]
# Now we made a table showing the 30 of the closest Repressor to each gene

# %%
closest = repr_assoc_df.loc[repr_assoc_df.groupby("gene")["abs_distance"].idxmin()]
print("closest Repressor to each gene (first 30):\n", closest.head(30))
# Out:
# closest Repressor to each gene (first 30):
#                             ocr_id            gene  chrom  distance  \
# 8837    ImmGenATAC1219.peak_85692   0610039H22Rik  chr11     -4378
# 35785  ImmGenATAC1219.peak_367960   0610040J01Rik   chr5       -18
# 30579  ImmGenATAC1219.peak_307976   1110032F04Rik   chr3       410
# 6114    ImmGenATAC1219.peak_55487   1500009L16Rik  chr10     27517
# 20275  ImmGenATAC1219.peak_203766   1600002D24Rik  chr16    -41186
# 20566  ImmGenATAC1219.peak_206469   1700010I14Rik  chr17     -1483
# 42240  ImmGenATAC1219.peak_439918   1700012D14Rik   chr7     61999
# 32414  ImmGenATAC1219.peak_325846   1700012D16Rik   chr3      -607
# 943      ImmGenATAC1219.peak_7328   1700019D03Rik   chr1    -32299
# 2935    ImmGenATAC1219.peak_25632   1700025G04Rik   chr1     -5194
# 35847  ImmGenATAC1219.peak_368249   1700027F09Rik   chr5    -90975
# 5501    ImmGenATAC1219.peak_46782   1700027J07Rik  chr10    -22378
# 37665  ImmGenATAC1219.peak_389320   1700028E10Rik   chr5    -68122
# 9402    ImmGenATAC1219.peak_98787   1700030C10Rik  chr12        78
# 25576  ImmGenATAC1219.peak_259226   1700061F12Rik   chr2     -1703
# 10154  ImmGenATAC1219.peak_106881   1700086L19Rik  chr12    -91598
# 15338  ImmGenATAC1219.peak_159007   1700108F19Rik  chr14      1151
# 6335    ImmGenATAC1219.peak_56624   1700113H08Rik  chr10     50540
# 18180  ImmGenATAC1219.peak_186856   1810013L24Rik  chr16     10427
# 6311    ImmGenATAC1219.peak_56456   1810014B01Rik  chr10    -84497
# 45922  ImmGenATAC1219.peak_483964   1810046K07Rik   chr9     65572
# 46191  ImmGenATAC1219.peak_487223   2300009A05Rik   chr9     93198
# 36503  ImmGenATAC1219.peak_374480   2310034O05Rik   chr5     56651
# 3629    ImmGenATAC1219.peak_32715   2310043L19Rik   chr1    -14310
# 9451    ImmGenATAC1219.peak_99023   2410018L13Rik  chr12       160
# 21388  ImmGenATAC1219.peak_220519   2410021H03Rik  chr17    -11290
# 18342  ImmGenATAC1219.peak_189976   2510009E07Rik  chr16     -7082
# 9069    ImmGenATAC1219.peak_92185   2610035D17Rik  chr11    -93328
# 45043  ImmGenATAC1219.peak_475335  2610044O15Rik8   chr8        12
# 32678  ImmGenATAC1219.peak_328391   2610301B20Rik   chr4     24556
#
#        abs_distance  correlation
# 8837           4378    -0.284014
# 35785            18    -0.392487
# 30579           410    -0.311457
# 6114          27517    -0.458434
# 20275         41186    -0.408454
# 20566          1483    -0.155801
# 42240         61999    -0.213853
# 32414           607    -0.407148
# 943           32299    -0.038149
# 2935           5194    -0.636649
# 35847         90975    -0.168769
# 5501          22378    -0.100343
# 37665         68122    -0.014275
# 9402             78    -0.421163
# 25576          1703    -0.059079
# 10154         91598    -0.174372
# 15338          1151    -0.235589
# 6335          50540    -0.152651
# 18180         10427    -0.303571
# 6311          84497    -0.408850
# 45922         65572    -0.418950
# 46191         93198    -0.579132
# 36503         56651    -0.506490
# 3629          14310    -0.027177
# 9451            160    -0.139000
# 21388         11290    -0.129487
# 18342          7082    -0.085249
# 9069          93328    -0.392382
# 45043            12    -0.084614
# 32678         24556    -0.637022

# %% [markdown]
# Next we wanted to see if more than 1 repressor were associated with the same gene. We solved this by visualizing  plot that shows that there are many more genes with a small amount of associated Repressors. But some genes auch as Foxp1 associated with 157 Repressors.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

cre_count_per_gene = repr_assoc_df.groupby("gene")["ocr_id"].nunique().reset_index()
cre_count_per_gene.columns = ["gene", "num_cre"]

multi_cre_genes = cre_count_per_gene[cre_count_per_gene["num_cre"] > 1]

plt.figure(figsize=(10, 5))
sns.histplot(cre_count_per_gene["num_cre"], bins=30, color="skyblue", edgecolor="black")
plt.title("Distribution of associated Repressors per gene")
plt.xlabel("Number of Repressors per gene")
plt.ylabel("Quantity of genes")
plt.tight_layout()
plt.savefig("Distribution_associated_Repressors_per_Gene.png", dpi=300)
plt.show()

top_genes = multi_cre_genes.sort_values("num_cre", ascending=False).head(20)

plt.figure(figsize=(8, 6))
sns.heatmap(top_genes.set_index("gene"), annot=True, fmt="d", cmap="coolwarm", cbar=False)
plt.title("Top 20 genes with more associated Repressors")
plt.xlabel("Number of Repressors")
plt.tight_layout()
plt.savefig("Genes_more_Repressors.png", dpi=300)
plt.show()

# %% [markdown]
# Lastly we wanted to visualize the top 100 Repressors with the highest correlation to genes in a heatmap. This heatmap also shows us how some genes correlate with more than one Repressor, which confirms the information that we had obtained before.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

top_repr_assoc = repr_assoc_df.sort_values("correlation").head(100)

pivot_repr = top_repr_assoc.pivot(index="ocr_id", columns="gene", values="correlation")

plt.figure(figsize=(12, 8))
sns.heatmap(pivot_repr, cmap="coolwarm", center=0)
plt.title("Top 100 Repressors: OCR ↔ Gene Correlation")
plt.xlabel("Gene")
plt.ylabel("OCR (Putative Repressor)")
plt.tight_layout()
plt.savefig("Repressor_Gene_Correlation.png", dpi=300)
plt.show()

# %% [markdown]
# This plot combines the heatmaps for most associated Repressors and Activators

# %%
combined_pivot = pd.concat([pivot_repr, pivot])

plt.figure(figsize=(14, 10))
sns.heatmap(combined_pivot, cmap="coolwarm", center=0)
plt.title("OCR ↔ Gene Correlation (Activators + Repressors)")
plt.xlabel("Gene")
plt.ylabel("OCR")
plt.tight_layout()
plt.savefig("Combined_OCR_Gene_Correlation.png", dpi=300)
plt.show()

# %%
ocr_df["ocr_id"] = ocr_df["ocr_id"].astype(str)
assoc_df["ocr_id"] = assoc_df["ocr_id"].astype(str)
repr_assoc_df["ocr_id"] = repr_assoc_df["ocr_id"].astype(str)


activ_df = assoc_df[assoc_df["correlation"] > 0].copy()
repr_df = repr_assoc_df[repr_assoc_df["correlation"] < 0].copy()


activ_counts = activ_df["annotation"].value_counts(normalize=True) * 100
repr_counts = repr_df["annotation"].value_counts(normalize=True) * 100


counts_df = pd.concat([activ_counts, repr_counts], axis=1)
counts_df.columns = ["Activator", "Repressor"]
counts_df = counts_df.fillna(0)
counts_df = counts_df.sort_index()


import matplotlib.pyplot as plt

counts_df.plot(kind="bar", figsize=(8,6), color=["steelblue", "salmon"])
plt.title("Genomic Distribution of Activating vs Repressing OCRs")
plt.xlabel("Genomic Category")
plt.ylabel("% of associated OCRs")
plt.xticks(rotation=45)
plt.legend(title="Type of OCR")
plt.tight_layout()
plt.savefig("OCRs_Activators_vs_Repressors_per_Category.png", dpi=300)
plt.show()
